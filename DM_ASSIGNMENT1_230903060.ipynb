# %% [markdown]
# Assignment 1
# ====
# _This pdf is generated directly from ipynb file._
#
# _If there is something unshown in the file, can also see this at [My Github](https://github.com/Cat3DoG4/Data-Mining-Assignment-1)_

# %% [markdown]
# **1)**
# ----

# %%
import pandas as pd
from sklearn.datasets import load_wine
from matplotlib import pyplot as plt

data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = pd.Series(data.target)
display(df)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# a)

# %%
print('The frequency of the three types of wine is {:.3f}, {:.3f} and {:.3f} each.'.format(sum(df['target'] == 0)/len(df), sum(df['target'] == 1)/len(df), sum(df['target'] == 2)/len(df)))
# Out:
# The frequency of the three types of wine is 0.331, 0.399 and 0.270 each.

# %% [markdown]
# We can see that only target is categorical. From the calculation, we can see the frequency of each value ( 0,1 and 2) is 0.331, 0.399 and 0.270 respectively.

# %% [markdown]
# b)

# %%
print("The mean of each numerical feature is:")
print(df.mean())  #calculate the mean of each variable
print("\n\nThe 75% quantile of each numerical feature is:")
print(df.quantile(q = 0.75))  #calculate 75% quantile of each variable

print("\n\nThe correlation between each two numerical features (Pearson) is:")
display(df.corr(method='pearson')) #calculate the Pearson correlation cofficient of each variable

print("\n\nThe covariance between each two numerical features is:")
display(df.cov())  #calculate the covariance of each variable
# Out:
# The mean of each numerical feature is:
# alcohol                          13.000618
# malic_acid                        2.336348
# ash                               2.366517
# alcalinity_of_ash                19.494944
# magnesium                        99.741573
# total_phenols                     2.295112
# flavanoids                        2.029270
# nonflavanoid_phenols              0.361854
# proanthocyanins                   1.590899
# color_intensity                   5.058090
# hue                               0.957449
# od280/od315_of_diluted_wines      2.611685
# proline                         746.893258
# target                            0.938202
# dtype: float64
#
#
# The 75% quantile of each numerical feature is:
# alcohol                          13.6775
# malic_acid                        3.0825
# ash                               2.5575
# alcalinity_of_ash                21.5000
# magnesium                       107.0000
# total_phenols                     2.8000
# ...

# %% [markdown]
# c) Use Boxplot to visualise the group observation.

# %%
#boxplot each variable of different categories
for col in df.columns:
  if col != 'target':
    ax= df.boxplot([col], by = ['target'], xlabel = 'target')

# %%
# separate by target
df_w0 = df.loc[df['target'] == 0]
df_w1 = df.loc[df['target'] == 1]
df_w2 = df.loc[df['target'] == 2]

# calculate the median of the remaining numerical feature
print("The median of each numerical feature of category 0 is:")
print(df_w0.median())
print("\n\nThe median of each numerical feature of category 1 is:")
print(df_w1.median())
print("\n\nThe median of each numerical feature of category 2 is:")
print(df_w2.median())
# Out:
# The median of each numerical feature of category 0 is:
# alcohol                           13.75
# malic_acid                         1.77
# ash                                2.44
# alcalinity_of_ash                 16.80
# magnesium                        104.00
# total_phenols                      2.80
# flavanoids                         2.98
# nonflavanoid_phenols               0.29
# proanthocyanins                    1.87
# color_intensity                    5.40
# hue                                1.07
# od280/od315_of_diluted_wines       3.17
# proline                         1095.00
# target                             0.00
# dtype: float64
#
#
# The median of each numerical feature of category 1 is:
# alcohol                          12.29
# malic_acid                        1.61
# ash                               2.24
# alcalinity_of_ash                20.00
# magnesium                        88.00
# total_phenols                     2.20
# ...

# %% [markdown]
# d)

# %%
# Define a function to find the biggest correlation given the pd dataframe correlation matrix

def find_biggest_corr(df_corr):
  cols=df_corr.columns

  #initialize
  corr_max = 0
  i_max = 0
  j_max = 0

  #Find by exploring each element.
  for i in range(len(col)):
    for j in range(i+1,len(col)):
      corr_i_j = df_corr[cols[i]].iloc[j]
      if abs(corr_max) < abs(corr_i_j):
        corr_max = corr_i_j
        i_max = i
        j_max = j

  return corr_max,i_max,j_max

# %%
# Find the pair of distinct numerical features with the highest correlation
df_corr = df.corr(method='pearson')

__, x, y = find_biggest_corr(df_corr)
print("The pair of distinct numerical features with the highest correlation is {} and {}.\n".format(df_corr.columns[x],df_corr.columns[y]))

# Plot
df.plot.scatter(df_corr.columns[x],df_corr.columns[y])
# Out:
# The pair of distinct numerical features with the highest correlation is ash and alcalinity_of_ash.
# <Axes: xlabel='ash', ylabel='alcalinity_of_ash'>

# %% [markdown]
# **2)**
# ----
#
# Consider the following sales data:
#
#
#
# > [5, 20, 1, 6, 13, 8, 9, 11, 17, 7, 2, 12]
#
#
#
#
#
# Its order is [1, 2, 5, 6, 7, 8, 9, 11, 12, 13, 17, 20] and has 12 elements,so
#
#
# > Using Equal-frequency binning method, each bin has 4 elements, then
# >> Bin 1 : 1, 2, 5, 6
#
# >> Bin 2 : 7, 8, 9, 11
#
# >> Bin 3 : 12, 13, 17, 20
#
# > When moothing by bin boundaries, each element should go to the nearest boundry of the bin, then
# >> Bin 1 : 1, 1, 6, 6
#
# >> Bin 2 : 7, 7, 7 (or 11), 11
#
# >> Bin 3 : 12, 12, 20, 20

# %% [markdown]
# **3)**
# ----
# Works on country-income.csv

# %%
df_ci = pd.read_csv('country-income.csv')
display(df_ci)
# Out:
#    Region   Age   Income Online Shopper
# 0   India  49.0  86400.0             No
# 1  Brazil  32.0  57600.0            Yes
# 2     USA  35.0  64800.0             No
# 3  Brazil  43.0  73200.0             No
# 4     USA  45.0      NaN            Yes
# 5   India  40.0  69600.0            Yes
# 6  Brazil   NaN  62400.0             No
# 7   India  53.0  94800.0            Yes
# 8     USA  55.0  99600.0             No
# 9   India  42.0  80400.0            Yes

# %%
#fill NAN value with column mean
for col in df_ci.columns:
  try:
    df_ci[col].fillna(df_ci[col].mean(), inplace=True)
    print('Column {} successfully filling NAN with mean'.format(col))
  except:
    print('Missing values in column {} cannot be filled'.format(col))

df_ci["Age"] = df_ci["Age"].astype(int)
df_ci["Income"] = df_ci["Income"].astype(int)
display(df_ci)
df_ci.to_csv("country_income_adjusted.csv", index = False) # This is used in exercise 7.
# Out:
# Missing values in column Region cannot be filled
# Column Age successfully filling NAN with mean
# Column Income successfully filling NAN with mean
# Missing values in column Online Shopper cannot be filled
#    Region  Age  Income Online Shopper
# 0   India   49   86400             No
# 1  Brazil   32   57600            Yes
# 2     USA   35   64800             No
# 3  Brazil   43   73200             No
# 4     USA   45   76533            Yes
# 5   India   40   69600            Yes
# 6  Brazil   43   62400             No
# 7   India   53   94800            Yes
# 8     USA   55   99600             No
# 9   India   42   80400            Yes

# %% [markdown]
# We can see from the dataframe that NANs appear on Age and Income and both have 1 NAN.
#
# For categorical data, Region is not sequencial and Online Shopper is Boolen. So I intend to set No for 0 and Yes for 1 for Onlone Shopper attribute.

# %%
#Replacing any categorical features with numerical features

#For Region, there is no order between values.
df_ci['Region'] = df_ci['Region'].astype("category").cat.codes+1

#For Online Shopper, set No as 0 and Yes as 1. Create a dictionary to realize this.
shopper_map = {"No":0, "Yes":1}
df_ci['Online Shopper'] = df_ci['Online Shopper'].map(shopper_map)
df_ci
# Out:
#    Region  Age  Income  Online Shopper
# 0       2   49   86400               0
# 1       1   32   57600               1
# 2       3   35   64800               0
# 3       1   43   73200               0
# 4       3   45   76533               1
# 5       2   40   69600               1
# 6       1   43   62400               0
# 7       2   53   94800               1
# 8       3   55   99600               0
# 9       2   42   80400               1

# %% [markdown]
# **4)**
# ----
# Works on shoesize.csv

# %%
df_ss = pd.read_csv('shoesize.csv')
display(df_ss)
# Out:
#      Index Gender  Size  Height
# 0        1      F   5.5    60.0
# 1        2      F   6.0    60.0
# 2        3      F   7.0    60.0
# 3        4      F   8.0    60.0
# 4        5      F   8.0    60.0
# ..     ...    ...   ...     ...
# 403    404      M  13.0    78.0
# 404    405      M  13.0    78.0
# 405    406      M  14.0    78.0
# 406    407      M  15.0    80.0
# 407    408      M  15.0    81.0
#
# [408 rows x 4 columns]

# %%
#separate into male and female
df_ss_F = df_ss.loc[df_ss['Gender'] == 'F',['Size','Height']]
df_ss_M = df_ss.loc[df_ss['Gender'] == 'M',['Size','Height']]
display(df_ss_F)
# Out:
#      Size  Height
# 0     5.5    60.0
# 1     6.0    60.0
# 2     7.0    60.0
# 3     8.0    60.0
# 4     8.0    60.0
# ..    ...     ...
# 182  10.0    72.0
# 183  11.0    72.0
# 184  11.0    72.0
# 185  10.0    74.0
# 186  11.0    74.0
#
# [187 rows x 2 columns]

# %%
#draw scatterplot separately
df_ss_F.plot.scatter("Size", "Height", label = "F", color = "r")
df_ss_M.plot.scatter(x = "Size", y = "Height", label = "M", color = "b")

#then put them in one plot
ax = df_ss_F.plot.scatter("Size", "Height", label = "F", marker = 'o', color = "r")
df_ss_M.plot.scatter(x = "Size", y = "Height", label = "M", color = "b", marker = 'x', ax = ax)
# Out:
# <Axes: xlabel='Size', ylabel='Height'>

# %%
#Calculate the Pearson's correlation coefficient.
print('Pearson\'s correlation coefficient of shoe size versus height for female is {:.3f} .'.format(df_ss_F.corr(method='pearson')['Size'].iloc[1]))
print('Pearson\'s correlation coefficient of shoe size versus height for male is {:.3f} .'.format(df_ss_M.corr(method='pearson')['Size'].iloc[1]))
# Out:
# Pearson's correlation coefficient of shoe size versus height for female is 0.708 .
# Pearson's correlation coefficient of shoe size versus height for male is 0.768 .

# %% [markdown]
# It can be inferred from the scatterplot that there is a positive relationship between shoe's Size and Height for both male and female, and male's Size and Height of shoes are bigger than female's in general.
#
# From the computed correlation coefficients, correlation correlation of male's shoes is bigger than female's, meaning Size and Height of male's shoes are more relavant.

# %% [markdown]
# **5)**
# ----
# PCA

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
# Use PCA and transfrom the dataframe.
from sklearn.decomposition import PCA

df_DropTarget = df.drop(['target'], axis=1, inplace=False) # do no use target in PCA
numComponents = 2
pca = PCA(n_components = numComponents)
pca.fit(df_DropTarget)

df_transform = pca.transform(df_DropTarget)
df_transform = pd.DataFrame(df_transform,columns=['pc1','pc2'],index=range(0,178))
df_transform['target'] = df['target']
display(df_transform)
# Out:
#             pc1        pc2  target
# 0    318.562979  21.492131       0
# 1    303.097420  -5.364718       0
# 2    438.061133  -6.537309       0
# 3    733.240139   0.192729       0
# 4    -11.571428  18.489995       0
# ..          ...        ...     ...
# 173   -6.980211  -4.541137       2
# 174    3.131605   2.335191       2
# 175   88.458074  18.776285       2
# 176   93.456242  18.670819       2
# 177 -186.943190  -0.213331       2
#
# [178 rows x 3 columns]

# %%
# Visualise
import matplotlib.pyplot as plt

colours = {0:'r', 1:'b', 2:'g'}

for col_target in colours:
    d = df_transform[df_transform['target']==col_target]
    plt.scatter(d['pc1'],d['pc2'],c=colours[col_target])

plt.xlabel("pc1")
plt.ylabel("pc2")
plt.legend(labels=['0','1','2'])

# %%
print("pc1 contains {:.2%} of total message.".format(df_transform["pc1"].var()/sum(df_DropTarget.var())))
print("pc2 contains {:.2%} of total message.".format(df_transform["pc2"].var()/sum(df_DropTarget.var())))
# Out:
# pc1 contains 99.81% of total message.
# pc2 contains 0.17% of total message.

# %% [markdown]
# I can obtain from the scatterplot that wines of target 0 can be relatively easy to be distinguished, but it is still hard to tell th difference between type 1 and type 2. This is possibly because these 2 components are still not good to separate the variables because pc1 contains 99.81% of the total message (variance), almost all the information. In this situation, standardisation should be performed before using PCA.

# %%
# Standardisation
for col in df_DropTarget.columns:
  df_DropTarget[col] = (df_DropTarget[col] - df_DropTarget[col].mean())/df_DropTarget[col].std()
display(df_DropTarget)

# Then apply PCA
pca.fit(df_DropTarget)

df_transform = pca.transform(df_DropTarget)
df_transform = pd.DataFrame(df_transform,columns=['pc1','pc2'],index=range(0,178))
df_transform['target'] = df['target']
display(df_transform)
print("pc1 contains {:.2%} of total message.".format(df_transform["pc1"].var()/sum(df_DropTarget.var())))
print("pc2 contains {:.2%} of total message.".format(df_transform["pc2"].var()/sum(df_DropTarget.var())))

for col_target in colours:
    d = df_transform[df_transform['target']==col_target]
    plt.scatter(d['pc1'],d['pc2'],c=colours[col_target])

plt.xlabel("pc1")
plt.ylabel("pc2")
plt.legend(labels=['0','1','2'])
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.514341   -0.560668  0.231400          -1.166303   1.908522
# 1    0.245597   -0.498009 -0.825667          -2.483841   0.018094
# 2    0.196325    0.021172  1.106214          -0.267982   0.088110
# 3    1.686791   -0.345835  0.486554          -0.806975   0.928300
# 4    0.294868    0.227053  1.835226           0.450674   1.278379
# ..        ...         ...       ...                ...        ...
# 173  0.873810    2.966176  0.304301           0.300954  -0.331985
# 174  0.491955    1.408636  0.413653           1.049555   0.158126
# 175  0.331822    1.739837 -0.388260           0.151234   1.418411
# 176  0.208643    0.227053  0.012696           0.151234   1.418411
# 177  1.391162    1.578712  1.361368           1.498716  -0.261969
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.806722    1.031908             -0.657708         1.221438
# ...

# %% [markdown]
# **6)**
# ----
#
#
# This conclusion can be inferred through the colour (or density) of the heatmap. When creating the heatmap, data is sorted by increasing parental level of education, so the left-up corner is the average distance between students whose parents only have some high school education, and the right-up (or the left-bottom) corner represents the average distance between students whose parents only have some high school education and students whose parents have a master's degree. It's obvious that the colour on the right-up is deeper than that on the left-up, meaning the former distance is larger than the latter, and we can draw this conclusion.

# %% [markdown]
# **7)**
# ----

# %%
# !pip install cubes
# !pip install sqlalchemy==1.3.20

#I need to import 2 times to successfully import this package and I don't know why.
try:
    from sqlalchemy import create_engine
    from cubes.tutorial.sql import create_table_from_csv
except:
    from sqlalchemy import create_engine
    from cubes.tutorial.sql import create_table_from_csv

# %% [markdown]
# a)
#
# The code of creating cubes are as belows, and the json file is presented at the next cell.

# %%
# Create cubes
import cubes
from cubes import Workspace

engine = create_engine('sqlite:///data.sqlite')
create_table_from_csv(engine,
                      "country_income_adjusted.csv",
                      table_name="country_income",
                      fields=[
                          ("Region", "string"),
                          ("Age", "integer"),
                          ("Income", "integer"),
                          ("Online_Shopper", "string")],
                      create_id=True
                     )

workspace = Workspace()
workspace.register_default_store("sql", url="sqlite:///data.sqlite")
workspace.import_model("model.json")
cube = workspace.cube("country_income")
browser = workspace.browser(cube)

# %%
with open("model.json", "r", encoding="utf-8") as f:
    model = f.read()
print(model)
# Out:
# {
#     "dimensions": [
#         {"name":"Region"},
#         {"name":"Age"},
#         {"name":"Income"},
#         {"name":"Online_Shopper"}
#     ],
#     "cubes": [
#         {
#             "name": "country_income",
#             "dimensions": ["Region", "Age", "Online_Shopper"],
#             "measures": [{"name":"Income"}],
#             "aggregates": [
#                     {
#                         "name": "average_income",
#                         "function": "avg",
#                         "measure": "Income"
#                     },
#                     {
#                         "name": "total_income",
#                         "function": "sum",
#                         "measure": "Income"
#                     },
#                     {
#                         "name": "maximum_income",
#                         "function": "max",
#                         "measure": "Income"
#                     },
#                     {
# ...

# %% [markdown]
# b)

# %%
# For the whole data cube
result = browser.aggregate()
print("For the whole data cube, the aggregate results are:")
print("Total income: {}".format(result.summary["total_income"]))
print("Average income: {}".format(result.summary["average_income"]))
print("Maximum income: {}".format(result.summary["maximum_income"]))
print("Minimum income: {}".format(result.summary["minimum_income"]))
print("\n")

# For the results per region
result = browser.aggregate(drilldown=["Region"])
for record in result:
    print(record)
print("\n")

# For the results per online activity
result = browser.aggregate(drilldown=["Online_Shopper"])
for record in result:
    print(record)
print("\n")

# For all people aged between 40 and 50
cuts = [cubes.RangeCut("Age", [40], [50])]
cell = cubes.Cell(cube, cuts)
result = browser.aggregate(cell)
print("The aggregate results for people aged from 40 to 50 is:")
print(result.summary)
# Out:
# For the whole data cube, the aggregate results are:
# Total income: 765333
# Average income: 76533.3
# Maximum income: 99600
# Minimum income: 57600
#
#
# {'Region': 'Brazil', 'average_income': 64400.0, 'total_income': 193200, 'maximum_income': 73200, 'minimum_income': 57600}
# {'Region': 'India', 'average_income': 82800.0, 'total_income': 331200, 'maximum_income': 94800, 'minimum_income': 69600}
# {'Region': 'USA', 'average_income': 80311.0, 'total_income': 240933, 'maximum_income': 99600, 'minimum_income': 64800}
#
#
# {'Online_Shopper': 'No', 'average_income': 77280.0, 'total_income': 386400, 'maximum_income': 99600, 'minimum_income': 62400}
# {'Online_Shopper': 'Yes', 'average_income': 75786.6, 'total_income': 378933, 'maximum_income': 94800, 'minimum_income': 57600}
#
#
# The aggregate results for people aged from 40 to 50 is:
# {'average_income': 74755.5, 'total_income': 448533, 'maximum_income': 86400, 'minimum_income': 62400}

# %% [markdown]
# **8)**
# ----
#
# Using 1-nearest neighbour classifier, the Euclidean distance between $x_3$ and other points is:
#
# $d_{13}=2,\ d_{23}=2\sqrt{5}$
#
# $x_1$ is the 1-nearest neighbour of $x_3$, so $x_3$ should be classified as the type of $x_1$, that is $y_3=y_1=1$.
#
# Similarly, $d_{14}=\sqrt{2},\ d_{24}=\sqrt{2}$. The two distances are the same, so they can both be the 1-nearest neighbour and $x_4$ is on the boundary of the classifier.
